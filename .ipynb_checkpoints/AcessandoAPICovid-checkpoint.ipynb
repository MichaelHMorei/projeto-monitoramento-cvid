# %%
# Importando as bibliotecas

# %%
import requests as r
import pandas as pd
from datetime import datetime
import numpy as np
from pandasql import sqldf
import pyodbc as odc
from matplotlib import gridspec
from matplotlib import pyplot as plt
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import fixed ,interact ,interactive

# %% [markdown]
# # Requisitando os dados na API

# %%
url = 'https://covid19-brazil-api.now.sh/api/report/v1'
df = r.request('GET',url)

# %% [markdown]
# # Convertendo o Json em um DataFrame

# %%
#Criando um DataFrame vazio.
df2 = pd.DataFrame()
i = 0
    
#Obetendo os dados da API
df = r.request('GET',url)
    
#Obtendo a data atual do sistema.
data_atual = datetime.today().strftime('%Y-%m-%d')

#Lendo linha a linha do dicionaro 'Data' vindo do arquivo Json.
#O dicionario e composto por chave e valor.

for i in range(len(df.json()['data'])):
        df1 = pd.DataFrame(df.json()['data'][i], index=[0])

        #Alterando o formato da data
        df1['datetime'] = pd.to_datetime(df1['datetime']).dt.strftime("%Y-%m-%d")

        #Adicionando os registros ao dataframe = df2
        df2 = df2.append(df1)

# %% [markdown]
# # Fazer Select no Banco para conferir valores repetidos.

# %%
def SelectBanco ():
    
    con_string = ('DRIVER={SQL Server};'
              'SERVER=DESKTOP-AF7BA3M;'
              'DATABASE=CovidDB;')

    cnxn = odc.connect(con_string)
    query = """SELECT * FROM Tb_Covid1"""
    
    #Passando o retorno da consulta para um dataframe = 'result'
    result = pd.read_sql(query, cnxn)
    
    return result

# %% [markdown]
# # Função para verificar a ultima data dos registros.

# %%
def IncrementoBanco (query,data_atual,df2):
    df0 = pd.DataFrame(query)
    if (df2['datetime'].max() != df0['datetime'].max()) :
            GravarNoBanco(df2)

# %% [markdown]
# # Insert - SQL

# %%
def GravarNoBanco(df):

        cnxn = odc.connect('DRIVER={SQL Server};'
                       'SERVER=DESKTOP-AF7BA3M;'
                        'DATABASE=CovidDB;')
        cursor = cnxn.cursor()

        for index , linha in df.iterrows():
            cursor.execute("insert into Tb_Covid1(uid, uf, state,cases,deaths,suspects,refuses,datetime) values (?,?,?,?,?,?,?,?)",linha.uid,linha.uf,linha.state,linha.cases,linha.deaths,linha.suspects,linha.refuses,linha.datetime)
            cursor.commit()

# %% [markdown]
# # Instancioando as funçoes.

# %%
# Query no banco de dados para verificar o registro com a maior data.
query = SelectBanco()

#Incrementando os dados no banco
IncrementoBanco(query,data_atual,df2)

# %% [markdown]
# # Consultando o banco para verificar os valores inseridos.

# %%
query = SelectBanco()
query.head(50)
# Out:
#       id  uid  uf                state    cases  deaths  suspects  refuses  \
# 0   1001   35  SP            São Paulo  5362377  167989      5334      596
# 1   1002   31  MG         Minas Gerais  3352544   61216       925      104
# 2   1003   41  PR               Paraná  2441061   43072       400      119
# 3   1004   43  RS    Rio Grande do Sul  2319676   39250       416      330
# 4   1005   33  RJ       Rio de Janeiro  2131863   73207      1254      148
# 5   1006   42  SC       Santa Catarina  1696325   21738       346       47
# 6   1007   29  BA                Bahia  1540547   29831       573       36
# 7   1008   52  GO                Goiás  1320210   26411       353       55
# 8   1009   23  CE                Ceará  1243770   26867       493       89
# 9   1010   32  ES       Espírito Santo  1045921   14391        71       21
# 10  1011   26  PE           Pernambuco   918045   21566        89       23
# 11  1012   15  PA                 Pará   762630   18215        43       23
# 12  1013   51  MT          Mato Grosso   725849   14609        45        8
# 13  1014   53  DF     Distrito Federal   695637   11638       327      107
# 14  1015   25  PB              Paraíba   601296   10201        85       11
# 15  1016   13  AM             Amazonas   581934   14169        18       26
# 16  1017   50  MS   Mato Grosso do Sul   528289   10521        93       26
# 17  1018   24  RN  Rio Grande do Norte   502618    8168       108       22
# 18  1019   21  MA             Maranhão   430626   10879       125       13
# 19  1020   11  RO             Rondônia   400317    7197        61        2
# 20  1021   22  PI                Piauí   368022    7735        12        2
# 21  1022   28  SE              Sergipe   326989    6342        15       11
# 22  1023   17  TO            Tocantins   304206    4149        13        0
# 23  1024   27  AL              Alagoas   297546    6921        43       22
# 24  1025   16  AP                Amapá   160375    2130        15        0
# 25  1026   14  RR              Roraima   155391    2147         9        0
# 26  1027   12  AC                 Acre   124633    1998        12        0
# 27  1028   35  SP            São Paulo  5362856  168000      5334      596
# 28  1029   31  MG         Minas Gerais  3352682   61216       925      104
# 29  1030   41  PR               Paraná  2442595   43075       400      119
# 30  1031   43  RS    Rio Grande do Sul  2321888   39254       416      330
# 31  1032   33  RJ       Rio de Janeiro  2131863   73207      1254      148
# 32  1033   42  SC       Santa Catarina  1697243   21741       346       47
# 33  1034   29  BA                Bahia  1541055   29834       573       36
# 34  1035   52  GO                Goiás  1320492   26415       353       55
# 35  1036   23  CE                Ceará  1243867   26876       493       89
# 36  1037   32  ES       Espírito Santo  1045767   14391        71       21
# 37  1038   26  PE           Pernambuco   918045   21566        89       23
# 38  1039   15  PA                 Pará   762883   18227        43       23
# 39  1040   51  MT          Mato Grosso   725849   14609        45        8
# 40  1041   53  DF     Distrito Federal   695637   11638       327      107
# 41  1042   25  PB              Paraíba   601340   10202        85       11
# 42  1043   13  AM             Amazonas   581958   14169        18       26
# 43  1044   50  MS   Mato Grosso do Sul   528334   10521        93       26
# 44  1045   24  RN  Rio Grande do Norte   502618    8169       108       22
# 45  1046   21  MA             Maranhão   430774   10879       125       13
# 46  1047   11  RO             Rondônia   400646    7199        61        2
# 47  1048   22  PI                Piauí   368022    7735        12        2
# 48  1049   28  SE              Sergipe   327005    6342        15       11
# 49  1050   17  TO            Tocantins   304206    4149        13        0
#
#       datetime
# 0   2022-04-22
# 1   2022-04-22
# 2   2022-04-22
# 3   2022-04-22
# 4   2022-04-22
# 5   2022-04-22
# 6   2022-04-22
# 7   2022-04-22
# 8   2022-04-22
# 9   2022-04-22
# 10  2022-04-22
# 11  2022-04-22
# 12  2022-04-22
# 13  2022-04-22
# 14  2022-04-22
# 15  2022-04-22
# 16  2022-04-22
# 17  2022-04-22
# 18  2022-04-22
# 19  2022-04-22
# 20  2022-04-22
# 21  2022-04-22
# 22  2022-04-22
# 23  2022-04-22
# 24  2022-04-22
# 25  2022-04-22
# 26  2022-04-22
# 27  2022-04-23
# 28  2022-04-23
# 29  2022-04-23
# 30  2022-04-23
# 31  2022-04-23
# 32  2022-04-23
# 33  2022-04-23
# 34  2022-04-23
# 35  2022-04-23
# 36  2022-04-23
# 37  2022-04-23
# 38  2022-04-23
# 39  2022-04-23
# 40  2022-04-23
# 41  2022-04-23
# 42  2022-04-23
# 43  2022-04-23
# 44  2022-04-23
# 45  2022-04-23
# 46  2022-04-23
# 47  2022-04-23
# 48  2022-04-23
# 49  2022-04-23

# %% [markdown]
# # Grafico de casos

# %%
#Recebendo os dados do banco.
dfG = SelectBanco()

#Crindo o estilo da descrição dos filtros.
style ={'desciption_width' :'initial'}

#Criando o filtro.
Filtro_Date = widgets.SelectionSlider(
        options = dfG['datetime'].sort_values().unique().tolist(),
        value   =   '2022-04-22',
        description='Data',
        disabled=False,
        continuous_update=False,
        orientation='horizontal',
        readout=True)

def plot_Grafico(data,Filtro ):

    df1 = data[data['datetime'] == Filtro].copy()
    plt.figure(figsize=(21,12))
    plt.bar(df1['uf'],df1['cases'])
    plt.xlabel('UF')
    plt.ylabel('Quantidade') 
    plt.title('Quantidade de casos por Dia/UF')
    plt.xticks(rotation=60);

# %%
widgets.interactive( plot_Grafico, data = fixed(dfG), Filtro=Filtro_Date )
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Data', options=('2022-04-22', '202…

# %%
#dfG[['cases','uf','datetime']].groupby('cases').sum().reset_index()
